# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv('marketing_campaign.csv',delimiter = '\t')

# %%
pd.options.display.max_columns = 100
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
df.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
## removing columns with zero standard deviation

df.drop(columns = ['Z_CostContact','Z_Revenue'],axis = 1,inplace = True)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Response                0
# dtype: int64

# %%
## impute missing values with the mean

df['Income'] = df['Income'].fillna(df['Income'].mean())
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Response               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
## decreasing dimensions and thus complexity of the data

df['Kids'] = df['Kidhome'] + df['Teenhome']
df['Expenses'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']
df['TotalAcceptedCmp'] = df['AcceptedCmp1'] + df['AcceptedCmp2'] + df['AcceptedCmp3'] + df['AcceptedCmp4'] + df['AcceptedCmp5'] + df['Response']
df['NumTotalPurchases'] = df['NumWebPurchases'] + df['NumCatalogPurchases'] + df['NumStorePurchases'] + df['NumDealsPurchases']

# %%
## deleting extra columns

col_del = ["AcceptedCmp1" , "AcceptedCmp2", "AcceptedCmp3" , "AcceptedCmp4","AcceptedCmp5", "Response","NumWebVisitsMonth", "NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumDealsPurchases" , "Kidhome", "Teenhome","MntWines", "MntFruits", "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProds"]
df=df.drop(columns=col_del,axis=1)
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income Dt_Customer  Recency  \
# 0  5524        1957  Graduation         Single  58138.0  04-09-2012       58
# 1  2174        1954  Graduation         Single  46344.0  08-03-2014       38
# 2  4141        1965  Graduation       Together  71613.0  21-08-2013       26
# 3  6182        1984  Graduation       Together  26646.0  10-02-2014       26
# 4  5324        1981         PhD        Married  58293.0  19-01-2014       94
#
#    Complain  Kids  Expenses  TotalAcceptedCmp  NumTotalPurchases
# 0         0     0      1617                 1                 25
# 1         0     2        27                 0                  6
# 2         0     0       776                 0                 21
# 3         0     1        53                 0                  8
# 4         0     1       422                 0                 19

# %%
cat_col = []
num_col = []

for i in df.columns:
    if df[i].dtype == 'int64':
        num_col.append(i)

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1        
for column in num_col:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()
    

#sns.distplot(df['Income'])

# %%
## normalizing the columns
df_dropped_columns = df.copy()

outlier_index = df_dropped_columns[df_dropped_columns['Expenses'] > 1700].index
df_dropped_columns.drop(outlier_index, inplace=True)


outlier_index = df_dropped_columns[df_dropped_columns['Year_Birth'] < 1930].index
df_dropped_columns.drop(outlier_index, inplace=True)

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1        
for column in num_col:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_dropped_columns[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
##simplifying even further

df_dropped_columns['Education'] = df_dropped_columns['Education'].replace(['PhD','2n Cycle','Graduation', 'Master'],'PG')  
df_dropped_columns['Education'] = df_dropped_columns['Education'].replace(['Basic'], 'UG')

df_dropped_columns['Marital_Status'] = df_dropped_columns['Marital_Status'].replace(['Married', 'Together'],'relationship')
df_dropped_columns['Marital_Status'] = df_dropped_columns['Marital_Status'].replace(['Divorced', 'Widow', 'Alone', 'YOLO', 'Absurd'],'Single')

# %%
df_dropped_columns
# Out:
#          ID  Year_Birth Education Marital_Status   Income Dt_Customer  \
# 0      5524        1957        PG         Single  58138.0  04-09-2012
# 1      2174        1954        PG         Single  46344.0  08-03-2014
# 2      4141        1965        PG   relationship  71613.0  21-08-2013
# 3      6182        1984        PG   relationship  26646.0  10-02-2014
# 4      5324        1981        PG   relationship  58293.0  19-01-2014
# ...     ...         ...       ...            ...      ...         ...
# 2235  10870        1967        PG   relationship  61223.0  13-06-2013
# 2236   4001        1946        PG   relationship  64014.0  10-06-2014
# 2237   7270        1981        PG         Single  56981.0  25-01-2014
# 2238   8235        1956        PG   relationship  69245.0  24-01-2014
# 2239   9405        1954        PG   relationship  52869.0  15-10-2012
#
#       Recency  Complain  Kids  Expenses  TotalAcceptedCmp  NumTotalPurchases
# ...

# %%
sns.barplot(x = df_dropped_columns['Expenses'],y = df_dropped_columns['Education'])
plt.title('Total Expense based on the Education Level')
# Out:
# Text(0.5, 1.0, 'Total Expense based on the Education Level')

# %%
px.pie(names = 'Marital_Status',data_frame = df_dropped_columns)
# Out:
# <div>                            <div id="67696f9e-9e72-4c5b-a352-491f5d56553a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67696f9e-9e72-4c5b-a352-491f5d56553a")) {                    Plotly.newPlot(                        "67696f9e-9e72-4c5b-a352-491f5d56553a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Marital_Status=%{label}<extra></extra>","labels":["Single","Single","relationship","relationship","relationship","relationship","Single","relationship","relationship","relationship","relationship","relationship","Single","Single","relationship","Single","relationship","relationship","Single","relationship","relationship","relationship","relationship","Single","relationship","Single","relationship","relation
# ...

# %%
px.pie(names = 'Education',data_frame = df_dropped_columns)
# Out:
# <div>                            <div id="a029eea0-93a9-42a8-b1ea-23500dddf111" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a029eea0-93a9-42a8-b1ea-23500dddf111")) {                    Plotly.newPlot(                        "a029eea0-93a9-42a8-b1ea-23500dddf111",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Education=%{label}<extra></extra>","labels":["PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","UG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG","PG",
# ...

# %%
sns.heatmap(df_dropped_columns.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### We can see that expenses and number of total purchases made by a customer are highly correlated but it won't be a problem for the model

# %%
df_dropped_columns.to_csv('Input_File')
